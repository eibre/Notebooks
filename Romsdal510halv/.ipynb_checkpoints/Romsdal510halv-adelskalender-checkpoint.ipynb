# %% [markdown]
# # Adelskalender Romsdal 5/10/halv
#
# For å legge til nye løp: last ned resultatene som txt-fil og lagre det med filnavn = dato på arrangement på fornatet 'yyyy-mm-dd'

# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_rows', 100)
path = r".\resultater"
filenames = os.listdir(path)

# %%
df = None
for filename in filenames:
    filepath = path+'\\'+filename
    date = filename.split('.')[0]
    df_temp = pd.read_csv(filepath, sep='\t')
    df_temp['Date']=date
    if df is None:
        df = df_temp
    else:
        df = pd.concat([df_temp,df], ignore_index=True)
df = df.drop(columns=['Bib', 'First name', 'Last name', 'Team name 2', 'Start', 'Finish', 'Year of birth', 'Lap 1', 'Lap 2', 'Split 1', 'Split 2'])

# %% [markdown]
# ## De 20 raskeste raskeste gjennom tidene:

# %%
print("De 20 raskeste på halvmaraton")
df[df['Distance'] == 'Halvmaraton'].sort_values('Time').reset_index().head(20)
# Out:
# De 20 raskeste på halvmaraton
#     index                      Name                       Team name  \
# 0     465         Sebastian Krogvig                             NaN
# 1      69              Einar Raknes                Ekko/Aureosen IL
# 2     196               Fredrik Bru                       Norodd IL
# 3     348  Bjørnar Kjønnøy Slettvåg              Oslostudentenes IK
# 4     244                 Per Myren                         Nofence
# 5      70                 Per Myren                               -
# 6     293                 Per Myren                              --
# 7     197                 Per Myren                    Kristiansund
# 8     158                 Per Myren                               -
# 9     198        Richard Williamson                    Hommelvik IL
# 10    199           Bjørn Tore Hoem                        Molde CK
# 11    407  Hågen Fjørkenstad Dypdal                    Bratsberg IL
# 12    245             Jan Erik Buan                             NaN
# 13    349            Knut Kongshaug                       Kårvåg IL
# 14    408              Torbjørn Eid  Trondheim og omegn sportsklubb
# 15    200        Ole Kristian Myren                    Kristiansund
# 16    409             Stian Gilberg                       Trondheim
# 17    246              Einar Engvig                       Norodd Il
# 18    350            Aleksander Lie                         Ispring
# 19    129            Ole-Erich Haas                   Markagaffe IL
#
#        Distance  Category Gender       Time        Date
# 0   Halvmaraton  23-34 år   Male    1:15:49  2020-06-24
# 1   Halvmaraton  35-39 år   Male    1:15:56  2022-10-01
# 2   Halvmaraton  23-34 år   Male    1:16:33  2021-10-09
# 3   Halvmaraton  35-39 år   Male    1:16:40  2020-10-04
# 4   Halvmaraton  35-39 år   Male    1:17:33  2021-08-11
# 5   Halvmaraton  35-39 år   Male    1:18:03  2022-10-01
# 6   Halvmaraton  35-39 år   Male    1:18:51  2021-06-05
# 7   Halvmaraton  35-39 år   Male    1:19:22  2021-10-09
# 8   Halvmaraton  35-39 år   Male    1:19:41  2022-04-30
# 9   Halvmaraton  35-39 år   Male    1:20:15  2021-10-09
# 10  Halvmaraton  23-34 år   Male    1:21:37  2021-10-09
# 11  Halvmaraton  23-34 år   Male  1:21:39.0  2020-08-30
# 12  Halvmaraton  50-54 år   Male    1:23:40  2021-08-11
# 13  Halvmaraton  45-49 år   Male    1:23:53  2020-10-04
# 14  Halvmaraton  45-49 år   Male  1:24:35.0  2020-08-30
# 15  Halvmaraton  23-34 år   Male    1:24:38  2021-10-09
# 16  Halvmaraton  23-34 år   Male  1:25:04.0  2020-08-30
# 17  Halvmaraton  45-49 år   Male    1:25:17  2021-08-11
# 18  Halvmaraton  23-34 år   Male    1:25:38  2020-10-04
# 19  Halvmaraton  40-44 år   Male    1:25:43  2022-06-06

# %%
print('De 20 raskeste på 10 km')
df[df['Distance'].str.contains('10 km')].sort_values('Time').reset_index().head(20)
# Out:
# De 20 raskeste på 10 km
#     index                       Name  \
# 0     420                Johan Bugge
# 1     135           Alexander Stavik
# 2     136  David André Aasen Arnevåg
# 3     252  David André Aasen Arnevåg
# 4     421   Bjørnar Kjønnøy Slettvåg
# 5       0            Fredrik Bruseth
# 6     165       Bjørn Erik Langstein
# 7     253            Sturle Starheim
# 8      91              Eivind Monsås
# 9      92             Børge Godejord
# 10     93                Atle Smenes
# 11    166              Eskil Engdahl
# 12    212               Einar Raknes
# 13    213             Martin Bruseth
# 14    305             Martin Bruseth
# 15    422            Morten Eilifsen
# 16    423            Sturle Starheim
# 17    306            Håkon Tømmervåg
# 18    254              Eskil Engdahl
# 19      1              Øyvind Øverås
#
#                                    Team name Distance      Category Gender  \
# 0                                        NaN    10 km      23-34 år   Male
# 1                                 Elnesvågen    10 km      35-39 år   Male
# 2   Romsdal Randoneeklubb / Mopil/ Cubastole    10 km      23-34 år   Male
# 3             Mopil / Cubastolen / Melhus IL    10 km      23-34 år   Male
# 4                                        NaN    10 km      35-39 år   Male
# 5                     Romsdal Randonee klubb    10 km      23-34 år   Male
# 6                              Tomrefjord IL    10 km      23-34 år   Male
# 7                                  Gossen IL    10 km      45-49 år   Male
# 8                      Romsdal Randoneeklubb    10 km      23-34 år   Male
# 9              Trondheim & Omeng Sportsklubb    10 km      23-34 år   Male
# 10                                 Rustad IL    10 km      23-34 år   Male
# 11                             Torvikbukt Il    10 km  20-22 år U23   Male
# 12                          Ekko/Aureosen IL    10 km      35-39 år   Male
# 13                      Romsdal Randoneklubb    10 km      35-39 år   Male
# 14                      Romsdal Randoneklubb    10 km      35-39 år   Male
# 15                                       NaN    10 km      35-39 år   Male
# 16                                       NaN    10 km      45-49 år   Male
# 17                                       NaN    10 km      23-34 år   Male
# 18                             Torvikbukt Il    10 km  20-22 år U23   Male
# 19                                Eidsvåg IL    10 km      23-34 år   Male
#
#        Time        Date
# 0   0:31:33  2020-06-24
# 1   0:33:48  2022-04-30
# 2   0:33:50  2022-04-30
# 3   0:34:07  2021-06-05
# 4   0:34:20  2020-06-24
# 5   0:34:35  2022-10-01
# 6   0:35:03  2021-10-09
# 7   0:35:09  2021-06-05
# 8   0:35:24  2022-06-06
# 9   0:35:32  2022-06-06
# 10  0:35:33  2022-06-06
# 11  0:35:38  2021-10-09
# 12  0:35:47  2021-08-11
# 13  0:35:56  2021-08-11
# 14  0:36:04  2020-10-04
# 15  0:36:07  2020-06-24
# 16  0:36:38  2020-06-24
# 17  0:36:50  2020-10-04
# 18  0:36:50  2021-06-05
# 19  0:37:01  2022-10-01

# %%
print("De 20 raskeste på 5 km")
df[df['Distance'].str.contains('5 km')].sort_values('Time').reset_index().head(20)
# Out:
# De 20 raskeste på 5 km
#     index                     Name                       Team name Distance  \
# 0     276         Kristian Woldvik                         Svorkmo     5 km
# 1     230            Knut Hjertvik                   OSI Friidrett     5 km
# 2     277             Erik Kårvatn                       Rindal IL     5 km
# 3     115          Live Solheimdal       Steinkjer Friidrettsklubb     5 km
# 4     278          Live Solheimdal                        SK Vidar     5 km
# 5     150          Live Solheimdal       Steinkjer Friidrettsklubb     5 km
# 6      37              Håkon Myrmo                      Rennebu IL     5 km
# 7     333         Alexander Stavik                     Lillehammer     5 km
# 8      38             André Løseth      Trollveggen Triathlonklubb     5 km
# 9      39          Benjamin Werner      Trollveggen Triatlonklubb      5 km
# 10    443          Preben Grønseth                             NaN     5 km
# 11    334          Preben Grønseth                          Bud Il     5 km
# 12    116           Brage Bjerkeli               Molde og Omegn IF     5 km
# 13    279          Mads Gjethammer  Molde Og Omegn Idrettsforening     5 km
# 14    444           Thomas Hetland                             NaN     5 km
# 15    231            Magnus Nygård                          Bud IL     5 km
# 16    232              Jarl Sæther                    Klubba Sport     5 km
# 17    280           Knut Kongshaug                       Kårvåg IL     5 km
# 18    281  Kristian Skjeflo Unhjem                    Isfjorden IL     5 km
# 19     40           Knut Kongshaug                       Kårvåg IL     5 km
#
#            Category  Gender     Time        Date
# 0          35-39 år    Male  0:15:42  2021-06-05
# 1          23-34 år    Male  0:15:45  2021-08-11
# 2   18-19 år junior    Male  0:16:15  2021-06-05
# 3          23-34 år  Female  0:16:48  2022-06-06
# 4          23-34 år  Female  0:16:49  2021-06-05
# 5          23-34 år  Female  0:16:51  2022-04-30
# 6          23-34 år    Male  0:17:17  2022-10-01
# 7          23-34 år    Male  0:17:28  2020-10-04
# 8          40-44 år    Male  0:17:32  2022-10-01
# 9          23-34 år    Male  0:17:33  2022-10-01
# 10     20-22 år U23    Male  0:17:33  2020-06-24
# 11     20-22 år U23    Male  0:17:48  2020-10-04
# 12         14-15 år    Male  0:17:53  2022-06-06
# 13         14-15 år    Male  0:18:09  2021-06-05
# 14         40-44 år    Male  0:18:12  2020-06-24
# 15         23-34 år    Male  0:18:13  2021-08-11
# 16         23-34 år    Male  0:18:15  2021-08-11
# 17         45-49 år    Male  0:18:21  2021-06-05
# 18            13 år    Male  0:18:23  2021-06-05
# 19         50-54 år    Male  0:18:28  2022-10-01

# %% [markdown]
# ## Deltakerantall

# %%
print("Antall unike deltakere: " + str(len(pd.unique(df['Name']))))
print("Antall løp: " + str(len(filenames)))
# Out:
# Antall unike deltakere: 307
# Antall løp: 9

# %%
print("Mest populær distanse:")
df.groupby('Distance')['Distance'].count().sort_values(ascending=False)
# Out:
# Mest populær distanse:
# Distance
# 10 km          216
# 5 km           139
# Halvmaraton    102
# Maraton         11
# 5 km U10         7
# Name: Distance, dtype: int64

# %%
print('Ivrigste deltakere')
df.groupby('Name')['Name'].count().sort_values(ascending=False).head(20)
# Out:
# Ivrigste deltakere
# Name
# Kolbjørn Hjertvik           6
# Runar Dahl Røsand           6
# Marianne Standal            5
# Richard W. Naas             5
# Knut Vidar Haukebø Siem     5
# Per Myren                   5
# Live Solheimdal             5
# Louise Skak                 5
# Thomas Sandhaug             5
# Emil Aslaksen Røed          4
# Asbjørn Slåttå              4
# Jan Erik Buan               4
# Håkon Myrmo                 4
# Thomas Kristoffer Tennøy    4
# Brage Bjerkeli              4
# Knut Kongshaug              4
# Torstein Svendsgaard        4
# Victoria Heggdal Voie       4
# Yngve Laingen               4
# Lars Steinar Laingen        4
# Name: Name, dtype: int64

# %%
print("Utvikling i deltakerantall")
df.groupby('Date')['Date'].count()
# Out:
# Utvikling i deltakerantall
# Date
# 2020-06-24    55
# 2020-08-30    53
# 2020-10-04    62
# 2021-06-05    53
# 2021-08-11    40
# 2021-10-09    47
# 2022-04-30    30
# 2022-06-06    44
# 2022-10-01    91
# Name: Date, dtype: int64

# %% [markdown]
# ## Løyperekorder

# %%
print("Løyperekorder")
#df.loc[df['Time'] == df.groupby(['Distance','Gender'])['Time'].min().reset_index()['Time']]
df.groupby(['Distance','Gender'])['Time'].min()
# Out:
# Løyperekorder
# Distance     Gender
# 10 km        Female      0:38:55
#              Male        0:31:33
# 5 km         Female      0:16:48
#              Male        0:15:42
# 5 km U10     Female      0:26:17
#              Male        0:21:03
# Halvmaraton  Female    1:28:44.0
#              Male        1:15:49
# Maraton      Female      3:18:37
#              Male        2:54:52
# Name: Time, dtype: object

# %%
df['Distance'].unique()
# Out:
# array(['10 km', '5 km', '5 km U10', 'Halvmaraton', 'Maraton'],
#       dtype=object)

# %%
for distance in df['Distance'].unique():
    for gender in df['Gender'].unique():
        df2 = df.loc[(df['Distance'] == distance) & (df['Gender'] == gender) ].sort_values(by='Time', ascending=True)
        df2 = df2.drop(columns=['Gender','Distance', 'Team name']) 
        print("Løyperekort for {}, {}".format(distance, gender))
        print(df2.head(1))
        print("\n---\n")
# Out:
# Løyperekort for 10 km, Male
#             Name  Category     Time        Date
# 420  Johan Bugge  23-34 år  0:31:33  2020-06-24
#
# ---
#
# Løyperekort for 10 km, Female
#               Name  Category     Time        Date
# 99  Andrea Boutera  23-34 år  0:38:55  2022-06-06
#
# ---
#
# Løyperekort for 10 km, nan
# Empty DataFrame
# Columns: [Name, Category, Time, Date]
# Index: []
#
# ---
#
# Løyperekort for 5 km, Male
#                  Name  Category     Time        Date
# 276  Kristian Woldvik  35-39 år  0:15:42  2021-06-05
#
# ---
#
# Løyperekort for 5 km, Female
#                 Name  Category     Time        Date
# 115  Live Solheimdal  23-34 år  0:16:48  2022-06-06
#
# ---
#
# Løyperekort for 5 km, nan
# Empty DataFrame
# Columns: [Name, Category, Time, Date]
# Index: []
#
# ---
#
# Løyperekort for 5 km U10, Male
#               Name Category     Time        Date
# 67  Vetle Bjerkeli    10 år  0:21:03  2022-10-01
#
# ---
#
# Løyperekort for 5 km U10, Female
#                       Name Category     Time        Date
# 68  Anna Sofie Reistadbakk     9 år  0:26:17  2022-10-01
#
# ---
#
# Løyperekort for 5 km U10, nan
# Empty DataFrame
# Columns: [Name, Category, Time, Date]
# Index: []
#
# ---
#
# Løyperekort for Halvmaraton, Male
#                   Name  Category     Time        Date
# 465  Sebastian Krogvig  23-34 år  1:15:49  2020-06-24
#
# ---
#
# Løyperekort for Halvmaraton, Female
#             Name  Category       Time        Date
# 410  Louise Skak  40-44 år  1:28:44.0  2020-08-30
#
# ---
#
# Løyperekort for Halvmaraton, nan
# Empty DataFrame
# Columns: [Name, Category, Time, Date]
# Index: []
#
# ---
#
# Løyperekort for Maraton, Male
#                       Name  Category     Time        Date
# 88  Espen Avset Fredriksen  35-39 år  2:54:52  2022-10-01
#
# ---
#
# Løyperekort for Maraton, Female
#             Name  Category     Time        Date
# 363  Louise Skak  40-44 år  3:18:37  2020-10-04
#
# ---
#
# Løyperekort for Maraton, nan
# Empty DataFrame
# Columns: [Name, Category, Time, Date]
# Index: []
#
# ---

# %%
df.to_excel(r'c:\dev\adelskalender.xlsx')
